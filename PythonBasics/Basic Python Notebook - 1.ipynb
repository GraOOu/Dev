# %% [markdown]
# # Airthmetic Operators

# %%
print ('Hello my name is Keshav')
# Out:
# Hello my name is Keshav

# %%
print (1+1)
# Out:
# 2

# %%
(1+1)
# Out:
# 2

# %%
101-1
# Out:
# 100

# %%
100*100
# Out:
# 10000

# %%
100/99
# Out:
# 1.0101010101010102

# %%
(6 + 9 *3 + 99)
# Out:
# 132

# %%
6 ** 2
# Out:
# 36

# %%
6 % 2
# Out:
# 0

# %%
9%2
# Out:
# 1

# %%
13//2
# Out:
# 6

# %%
13/2
# Out:
# 6.5

# %% [markdown]
# ## Variables

# %%
a = 99
a
# Out:
# 99

# %%
a + 1
# Out:
# 100

# %%
name = 'keshav'
gender = 'male'

# %%
name , gender = 'keshav','male'

# %%
name
# Out:
# 'keshav'

# %%
gender
# Out:
# 'male'

# %%
blood type = "O+"
# Out:
#   File "<ipython-input-22-1ee377eaeb39>", line 1
#     blood type = "O+"
#              ^
# SyntaxError: invalid syntax

# %%
blood_type = "O+"

# %%
a += 99
a
# Out:
# 198

# %%
a -= 99
a
# Out:
# 99

# %% [markdown]
# # Numeric Data Types

# %%
x,y = 7,3
z= x/y
print(z)
# Out:
# 2.3333333333333335

# %%
print(type(x))
# Out:
# <class 'int'>

# %%
s = 7.0

print(type(s))
# Out:
# <class 'float'>

# %%
int(z)
# Out:
# 2

# %%
w = int(3.7)

# %%
w
# Out:
# 3

# %% [markdown]
# # String Data Types

# %%
name = 'keshav'

# %%
print(name)
print(type(name))
# Out:
# keshav
# <class 'str'>

# %%
name = "keshav"
print(name)
print(type(name))
# Out:
# keshav
# <class 'str'>

# %%
comment = "Keshav said "Hello to Python" "
# Out:
#   File "<ipython-input-42-83230e2b8685>", line 1
#     comment = "Keshav said "Hello to Python" "
#                                 ^
# SyntaxError: invalid syntax

# %%
comment = 'Keshav said "Hello to Python" '
comment
# Out:
# 'Keshav said "Hello to Python" '

# %%
str_1 = 'I\'am very good boy'
str_2 = 'and very kind'

full_str = str_1 + " " + str_2
full_str
# Out:
# "I'am very good boy and very kind"

# %%
full_str * 2
# Out:
# "I'am very good boy and very kindI'am very good boy and very kind"

# %%
print (len(full_str))
# Out:
# 32

# %% [markdown]
# # Boolean Data Types

# %%
keshav_is_very_good_boy = True

# %%
keshav_is_not_kind = False

# %%
keshav_is_very_good_boy
# Out:
# True

# %%
1>2
# Out:
# False

# %%
1 == 2
# Out:
# False

# %%
1 == 1.0
# Out:
# True

# %%
1 < 2
# Out:
# True

# %%
1 < 2 or 2 == 3
# Out:
# True

# %%
1 < 2 and 2 == 3
# Out:
# False

# %%
1 is 1
# Out:
# True

# %%
1 is not 2
# Out:
# True

# %%
1 is not 1
# Out:
# False

# %%
not 1 < 2
# Out:
# False
